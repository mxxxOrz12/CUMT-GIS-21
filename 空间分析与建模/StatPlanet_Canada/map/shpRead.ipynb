# %%
import geopandas as gpd
from matplotlib import pyplot as plt

# %%
map = gpd.read_file("./map.shp")

# %%
print(map.crs)
print(map.head())
map.plot()
plt.show()
# Out:
# None
#    CODE                      NAME geometry
# 0  CA01                   Alberta     None
# 1  CA11              Saskatchewan     None
# 2  CA03                  Manitoba     None
# 3  CA05  Newfoundland  & Labrador     None
# 4  CA09      Prince Edward Island     None
