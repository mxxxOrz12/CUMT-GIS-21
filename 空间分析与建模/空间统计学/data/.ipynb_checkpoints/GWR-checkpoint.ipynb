# %% [markdown]
# # 空间数据分析之空间回归
# ## 2018-2020纽约枪击犯罪事件分析
#
# 本实验基于纽约2018-2020的枪击犯罪数据，实现空间相关性分析，选取人口（pop）、收入（income）、平均就业率（employ）、教育程度（edu）四个参数进行地理空间加权回归（GWR，MGWR）模型的参数估计
#
# ### 1 数据处理

# %%
import pandas as pd
import geopandas as gpd
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm
import matplotlib as mpl
import mapclassify as mc
import shapely as shp
from legendgram import legendgram
import palettable.matplotlib as palmpl
import esda
import libpysal as lps
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
import warnings
warnings.filterwarnings('ignore')
plt.rcParams['font.sans-serif'] = ['SimHei']

# %% [markdown]
# 导入数据，并投影到WGS 84

# %%
zone = gpd.read_file('shoot.shp')
zone = zone.to_crs(epsg=4326)
zone.crs
zone[['GEO_ID','shoot_coun','pop','income','employ','edu','geometry']].head(2)
# Out:
#                  GEO_ID  shoot_coun          pop        income     employ  \
# 0  1400000US36085007700         5.0  1417.333333  66617.666667  47.733333
# 1  1400000US36085000900         0.0  1697.666667  70920.000000  57.700000
#
#          edu                                           geometry
# 0  13.440145  MULTIPOLYGON (((-74.08710 40.64033, -74.08721 ...
# 1  24.632207  MULTIPOLYGON (((-74.08720 40.63990, -74.08553 ...

# %% [markdown]
# 计算空间权重并计算空间滞后

# %%
wq =  lps.weights.Queen.from_dataframe(zone)
wq.transform = 'r'
y = zone['shoot_coun']
ylag = lps.weights.lag_spatial(wq, y)
ylag[0:2]
# Out:
# ('WARNING: ', 1662, ' is an island (no neighbors)')
# ('WARNING: ', 2080, ' is an island (no neighbors)')
# array([1., 3.])

# %%
zone['lag_shoot_count'] = ylag
f,ax = plt.subplots(1,2,figsize=(16,10))
zone.plot(column='shoot_coun', ax=ax[0], edgecolor='white',
        scheme="quantiles",  k=5, cmap='Reds')
ax[0].axis(zone.total_bounds[np.asarray([0,2,1,3])])
ax[0].set_title("纽约2018-2020枪击事件分布")
zone.plot(column='lag_shoot_count', ax=ax[1], edgecolor='white',
        scheme='quantiles', cmap='Reds', k=5)
ax[1].axis(zone.total_bounds[np.asarray([0,2,1,3])])
ax[1].set_title("空间滞后-纽约2018-2020枪击数量")
ax[0].axis('off')
ax[1].axis('off')
plt.show()

# %% [markdown]
# ### OLS Fitting

# %%
import statsmodels.formula.api as sm
reg = sm.ols(formula=" shoot_coun~ pop+income+employ+edu", data=zone).fit()
print(reg.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             shoot_coun   R-squared:                       0.185
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     124.0
# Date:                Wed, 27 Mar 2024   Prob (F-statistic):           1.62e-95
# Time:                        19:14:16   Log-Likelihood:                -4242.1
# No. Observations:                2194   AIC:                             8494.
# Df Residuals:                    2189   BIC:                             8523.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.2276      0.244      9.147      0.000       1.750       2.705
# pop            0.0002    1.6e-05     13.754      0.000       0.000       0.000
# income     -7.188e-06   1.15e-06     -6.238      0.000   -9.45e-06   -4.93e-06
# employ        -0.0179      0.004     -4.019      0.000      -0.027      -0.009
# edu           -0.0116      0.004     -3.233      0.001      -0.019      -0.005
# ==============================================================================
# Omnibus:                     1053.626   Durbin-Watson:                   1.480
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7029.077
# Skew:                           2.181   Prob(JB):                         0.00
# Kurtosis:                      10.607   Cond. No.                     7.16e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.16e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Geospatial Weighted Regression Model

# %%
import numpy as np
from mgwr.sel_bw import Sel_BW
from mgwr.gwr import GWR, MGWR
import pandas as pd
import libpysal as ps

# %%
zone['centro']=zone.centroid
zone['X']=zone.centro.x
zone['Y']=zone.centro.y
coords = list(zip(zone['X'],zone['Y']))
# Out:
# C:\Users\Ma\AppData\Local\Temp\ipykernel_27280\3165751559.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   zone['centro']=zone.centroid

# %%
y = np.array(zone['shoot_coun']).reshape((-1,1))
pop = np.array(zone['pop']).reshape((-1,1))
income = np.array(zone['income']).reshape((-1,1))
employ = np.array(zone['employ']).reshape((-1,1))
edu = np.array(zone['edu']).reshape((-1,1))
X = np.hstack([pop, income,employ, edu])

# %%
X = (X - X.mean(axis=0)) / X.std(axis=0)
y = y.reshape((-1,1))
y = (y - y.mean(axis=0)) / y.std(axis=0)
sel = Sel_BW(coords, y, X)
bw = sel.search()
print('bw:', bw)
gwr = GWR(coords, y, X, bw)
gwr_results = gwr.fit()
print('aicc:', gwr_results.aicc)
print('ENP:', gwr_results.ENP)
print('sigma2:', gwr_results.sigma2)
# Out:
# bw: 98.0
# aicc: 4958.978176802648
# ENP: 273.24664759284127
# sigma2: 0.48167672342090784

# %%
gwr_results.summary()
# Out:
# ===========================================================================
# Model type                                                         Gaussian
# Number of observations:                                                2194
# Number of covariates:                                                     5
#
# Global Regression Results
# ---------------------------------------------------------------------------
# Residual sum of squares:                                           1788.638
# Log-likelihood:                                                   -2889.065
# AIC:                                                               5788.129
# AICc:                                                              5790.168
# BIC:                                                             -15052.394
# R2:                                                                   0.185
# Adj. R2:                                                              0.183
#
# Variable                              Est.         SE  t(Est/SE)    p-value
# ------------------------------- ---------- ---------- ---------- ----------
# X0                                   0.000      0.019      0.000      1.000
# X1                                   0.266      0.019     13.754      0.000
# X2                                  -0.194      0.031     -6.238      0.000
# X3                                  -0.095      0.024     -4.019      0.000
# X4                                  -0.110      0.034     -3.233      0.001
#
# Geographically Weighted Regression (GWR) Results
# ---------------------------------------------------------------------------
# Spatial kernel:                                           Adaptive bisquare
# Bandwidth used:                                                      98.000
#
# Diagnostic information
# ---------------------------------------------------------------------------
# Residual sum of squares:                                            925.182
# Effective number of parameters (trace(S)):                          273.247
# Degree of freedom (n - trace(S)):                                  1920.753
# Sigma estimate:                                                       0.694
# Log-likelihood:                                                   -2165.902
# AIC:                                                               4880.296
# AICc:                                                              4958.978
# BIC:                                                               6441.715
# R2:                                                                   0.578
# Adjusted R2:                                                          0.518
# Adj. alpha (95%):                                                     0.001
# Adj. critical t value (95%):                                          3.320
#
# Summary Statistics For GWR Parameter Estimates
# ---------------------------------------------------------------------------
# Variable                   Mean        STD        Min     Median        Max
# -------------------- ---------- ---------- ---------- ---------- ----------
# X0                       -0.009      0.584     -1.268     -0.182      2.758
# X1                        0.250      0.293     -0.343      0.144      1.466
# X2                       -0.198      0.603     -2.999     -0.099      2.682
# X3                       -0.061      0.188     -0.911     -0.023      0.507
# X4                       -0.188      0.430     -2.078     -0.126      1.418
# ===========================================================================

# %%
first_location_params = gwr_results.params[0, :]
print(f"Intercept and coefficients for the first location: {first_location_params}")


# 获取第二个观察点的系数
second_location_params = gwr_results.params[1, :]
print(f"Intercept and coefficients for the second location: {second_location_params}")
# Out:
# Intercept and coefficients for the first location: [ 0.15837095  0.28179982 -0.84314293  0.07093115 -0.39279355]
# Intercept and coefficients for the second location: [ 0.2000673   0.30219166 -0.79489681  0.06672825 -0.42830497]

# %%
f, ax = plt.subplots(2, 2, figsize=(12, 8))
zone['pop_par'] = gwr_results.params[:, 1]
zone['income_par'] = gwr_results.params[:, 2]
zone['employ_par'] = gwr_results.params[:, 3]
zone['edu_par'] = gwr_results.params[:, 4]

ax1 = plt.subplot(2, 2, 1)
ax2 = plt.subplot(2, 2, 2)
ax3 = plt.subplot(2, 2, 3)
ax4 = plt.subplot(2, 2, 4)

# 在这里更改色带
cmap_choice = 'YlOrRd'

zone.plot('pop_par', ax=ax1, legend=True, cmap=cmap_choice)
ax1.set_title("pop coef.")
zone.plot('income_par', ax=ax2, legend=True, cmap=cmap_choice)
ax2.set_title("income coef.")
zone.plot('employ_par', ax=ax3, legend=True, cmap=cmap_choice)
ax3.set_title("employ coef.")
zone.plot('edu_par', ax=ax4, legend=True, cmap=cmap_choice)
ax4.set_title("edu coef.")

f.savefig('GWRcoef.png', dpi=300)

# %%
# 假设 zone 已经是一个GeoDataFrame，并且已经计算了GWR模型的参数
zone['pop_par'] = gwr_results.params[:, 1]
zone['income_par'] = gwr_results.params[:, 2]
zone['employ_par'] = gwr_results.params[:, 3]
zone['edu_par'] = gwr_results.params[:, 4]

fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# 人口参数绘制
zone.plot(column='pop_par', ax=axs[0, 0], legend=True)
axs[0, 0].set_title('Population Coefficient')

# 收入参数绘制
zone.plot(column='income_par', ax=axs[0, 1], legend=True)
axs[0, 1].set_title('Income Coefficient')

# 就业参数绘制
zone.plot(column='employ_par', ax=axs[1, 0], legend=True)
axs[1, 0].set_title('Employment Co efficient')

# 教育参数绘制
zone.plot(column='edu_par', ax=axs[1, 1], legend=True)
axs[1, 1].set_title('Education Coefficient')

plt.tight_layout()
plt.show()
plt.show()
